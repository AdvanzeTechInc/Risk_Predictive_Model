# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import re
import xgboost
import lightgbm as lgb
import catboost
from sklearn.model_selection import KFold

# %%
from utility.data_cleaning import *
from utility.data_preprocessing import *
from utility.model_building import *
from config.configuration import *

# %%
from datetime import datetime
today = datetime.today().strftime('%Y%m%d')

# %%
df=pd.read_excel(input_data_path)
df
# Out:
#      ClaimNumber                 LossDate  PolicyNumber  \
# 0        2003862  2019-04-18 00:00:00.000       5010232
# 1        2004989  2020-01-01 00:00:00.000       7146314
# 2        2004989  2020-01-01 00:00:00.000       7146314
# 3        2005666  2020-04-30 00:00:00.000       7120072
# 4        2006935  2021-01-27 00:00:00.000       7120072
# ..           ...                      ...           ...
# 202      2011122  2023-03-03 00:00:00.000       7228908
# 203      2011122  2023-03-03 00:00:00.000       7228908
# 204      2011123  2023-03-03 00:00:00.000       7228908
# 205      2011123  2023-03-03 00:00:00.000       7228908
# 206      2011137  2023-07-28 00:00:00.000       7231166
#
#              PolicyEntryDate     PolicyExpirationDate  \
# 0    2019-05-03 08:09:04.880  2019-07-01 00:00:00.000
# 1    2020-01-02 09:54:03.083  2020-05-04 00:00:00.000
# 2    2020-01-02 09:54:03.083  2020-05-04 00:00:00.000
# 3    2020-05-15 12:29:16.837  2020-10-10 00:00:00.000
# ...

# %%
df = df[selected_columns]
col_mode = df.columns
col_mode = col_mode.drop(['YearBuilt','Stories','LossAmount','E2Value','SquareFootage','BuildingLimit'])
#col_mode = col_mode.drop(['LossAmount'])
modes = df[col_mode].mode().iloc[0]
modes_dict = modes.to_dict()
print(modes_dict)
with open('./data/training/output/mode_values_dict_'+today+'.pkl', 'wb') as file:
    pickle.dump(modes_dict, file)
df = df.apply(lambda col: col.fillna(modes_dict[col.name]) if col.name in columns_to_string else col)
df
# Out:
# {'Jurisdiction': 'Pennsylvania', 'CoverageType': 'BOP-Building', 'Deductible': 'FixedDollar - 2500.00', 'Limit': 'Blanket Group 1 Blanket - 48075046.00', 'InjuryCause': 'WATER', 'Comments': 'ClassCode:65146', 'ConstructionTypeDesc': 'Frame', 'ZipCode': '18102'}
#           Jurisdiction  CoverageType              Deductible  \
# 0    Dist. of Columbia  BOP-Building   FixedDollar - 2500.00
# 1             Virginia  BOP-Building   FixedDollar - 5000.00
# 2             Virginia  BOP-Building   FixedDollar - 5000.00
# 3         Pennsylvania  BOP-Building   FixedDollar - 2500.00
# 4         Pennsylvania  BOP-Building   FixedDollar - 2500.00
# ..                 ...           ...                     ...
# 202               Ohio  BOP-Building  FixedDollar - 25000.00
# 203               Ohio  BOP-Building  FixedDollar - 25000.00
# 204               Ohio  BOP-Building  FixedDollar - 25000.00
# 205               Ohio  BOP-Building  FixedDollar - 25000.00
# ...

# %%
col_mean = df.columns
col_mean = col_mean.drop(["Jurisdiction","CoverageType","InjuryCause","Comments","ConstructionTypeDesc","ZipCode","Deductible","Limit"])
mean = df[col_mean].mean().iloc[0]
mean_dict=df[col_mean].mean().to_dict()
#mean_dict = {'MeanValue': mean}
print(mean_dict)
with open('./data/training/output/mean_values_dict_'+today+'.pkl', 'wb') as file:
    pickle.dump(mean_dict, file)
col_int = ['Stories', 'E2Value','SquareFootage','BuildingLimit','YearBuilt']
df = df.apply(lambda col: col.fillna(mean_dict[col.name]) if col.name in col_int else col)
df
# Out:
# {'YearBuilt': 1940.6376811594203, 'Stories': 1.9178743961352658, 'LossAmount': 30435.24920634921, 'E2Value': 1689218.0797101452, 'SquareFootage': 7488.768115942029, 'BuildingLimit': 1332229.0869565217}
#           Jurisdiction  CoverageType              Deductible  \
# 0    Dist. of Columbia  BOP-Building   FixedDollar - 2500.00
# 1             Virginia  BOP-Building   FixedDollar - 5000.00
# 2             Virginia  BOP-Building   FixedDollar - 5000.00
# 3         Pennsylvania  BOP-Building   FixedDollar - 2500.00
# 4         Pennsylvania  BOP-Building   FixedDollar - 2500.00
# ..                 ...           ...                     ...
# 202               Ohio  BOP-Building  FixedDollar - 25000.00
# 203               Ohio  BOP-Building  FixedDollar - 25000.00
# 204               Ohio  BOP-Building  FixedDollar - 25000.00
# 205               Ohio  BOP-Building  FixedDollar - 25000.00
# 206  Dist. of Columbia  BOP-Building   FixedDollar - 5000.00
#
# ...

# %%
df_clean= clean_data(df)
df_clean
# Out:
#           Jurisdiction  CoverageType              Deductible  \
# 0    dist. of columbia  bop-building   fixeddollar - 2500.00
# 1             virginia  bop-building   fixeddollar - 5000.00
# 2             virginia  bop-building   fixeddollar - 5000.00
# 3         pennsylvania  bop-building   fixeddollar - 2500.00
# 4         pennsylvania  bop-building   fixeddollar - 2500.00
# ..                 ...           ...                     ...
# 202               ohio  bop-building  fixeddollar - 25000.00
# 203               ohio  bop-building  fixeddollar - 25000.00
# 204               ohio  bop-building  fixeddollar - 25000.00
# 205               ohio  bop-building  fixeddollar - 25000.00
# 206  dist. of columbia  bop-building   fixeddollar - 5000.00
#
#                                      Limit InjuryCause  YearBuilt  Stories  \
# 0                  standard - 550637568.00       water       1965        8
# 1                    standard - 2560320.00        fire       1969        2
# ...

# %%
X_train, y_train, X_test, y_test= preprocess_and_save(df_clean)
# Out:
# {'Jurisdiction': LabelEncoder(), 'CoverageType': LabelEncoder(), 'InjuryCause': LabelEncoder(), 'ClassCode': LabelEncoder(), 'ConstructionTypeDesc': LabelEncoder(), 'ZipCode': LabelEncoder(), 'limit_type': LabelEncoder(), 'Deductible_type': LabelEncoder()}
# C:\Users\SmrutisikhaJena\Documents\GitHub\Risk_Predictive_Model\utility\data_preprocessing.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LossAmount'] = df['LossAmount'].apply(extract_amount)
#      Jurisdiction  CoverageType  InjuryCause  Stories  ClassCode  \
# 0               1             0            7        8         13
# 1               6             0            1        2          7
# 2               6             0            1        2          7
# ...

# %%
train_and_evaluate_model(X_train, y_train, X_test, y_test)
# Out:
# C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
with open('./data/training/output/catboost_20231206.pkl', 'rb') as file:
    model=pickle.load(file)
coefficients = model.feature_importances_
print(coefficients)
# Out:
# [7.87445967e-01 0.00000000e+00 3.17570976e+01 2.11847163e+01
#  1.32119738e+00 5.13118726e+00 1.59915245e+01 3.01701108e+00
#  4.12446470e+00 7.60510922e+00 1.20840355e-01 3.26425546e+00
#  2.00272530e-02 1.15278018e+00 4.52234279e+00]

# %%
with open('./data/training/output/lr_model_20231206.pkl', 'rb') as file:
    model=pickle.load(file)
coefficients = model.coef_
print(coefficients)
# Out:
# [-3.84967571e+03  1.87777664e-04 -9.60395452e+03  1.12448384e+04
#  -6.83275437e+02 -2.34852797e+04 -1.77314625e+02 -2.52617667e-03
#  -2.36793196e-01  4.62281648e-03  1.00014140e+04  2.99766281e-05
#   4.27670502e+03  1.78040790e+00  4.51782273e+01]
