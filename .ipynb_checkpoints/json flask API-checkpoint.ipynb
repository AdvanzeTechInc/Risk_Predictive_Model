# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from flask import Flask, request, render_template,jsonify
from flask_cors import CORS
import re
import math
from utility.data_cleaning import *
from utility.data_preprocessing import *
from utility.model_building import *
from config.configuration import *
app = Flask(__name__)
CORS(app)

#import model and encoder  
with open('./data/training/output/lgb_model_'+str(today)+'.pkl', 'rb') as file:
    model=pickle.load(file)
with open('./data/training/output/encoder_'+str(today)+'.pkl', 'rb') as file:
    label_encoders=pickle.load(file)
    
@app.route("/predict_api", methods=['POST'])
def RiskPrediction():
    json_ = request.json
    df= pd.DataFrame([json_])
    df_clean = clean_data(df)
    for col in label_encoders:
        df_clean[col] = label_encoders[col].transform(df_clean[col])
    predicted_loss_amount= model.predict(df_clean)
    output = predicted_loss_amount[0]

    print(output)
    
    return jsonify({"prediction":output})
if __name__ == '__main__':
    #app.run()
    app.run(host='0.0.0.0', port=80)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:80
#  * Running on http://192.168.1.179:80
# Press CTRL+C to quit
#   Jurisdiction  CoverageType             Deductible                 Limit  \
# 0     delaware  bop-building  fixeddollar - 1000.00  standard - 217000.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0        wind      1958       1  classcode:65141                frame   19973
#
#   E2Value SquareFootage BuildingLimit
# 0  217236          1480        217000
# 127.0.0.1 - - [05/Dec/2023 17:14:53] "POST /predict_api HTTP/1.1" 200 -
# -760.65343179626
#   Jurisdiction  CoverageType              Deductible                 Limit  \
# 0         ohio  bop-building  fixeddollar - 10000.00  standard - 136250.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0        hail      1978       1  classcode:65144                frame   43701
#
#      E2Value SquareFootage BuildingLimit
# 0  2018702.4          1090        136250
# 127.0.0.1 - - [05/Dec/2023 17:22:21] "POST /predict_api HTTP/1.1" 200 -
# 5872.145883460535
#      Jurisdiction  CoverageType             Deductible                 Limit  \
# 0  north carolina  bop-building  fixeddollar - 2500.00  standard - 309000.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0    vehicles      1920       2  classcode:65146                frame   27701
#
#   E2Value SquareFootage BuildingLimit
# 0  333720          2472        309000
# 127.0.0.1 - - [05/Dec/2023 17:33:49] "POST /predict_api HTTP/1.1" 200 -
# -6160.315393093325
#         Jurisdiction  CoverageType             Deductible  \
# 0  dist. of columbia  bop-building  fixeddollar - 2500.00
#
#                    Limit InjuryCause YearBuilt Stories         Comments  \
# 0  standard - 1500000.00       water      1900       3  classcode:69145
#
#   ConstructionTypeDesc ZipCode E2Value SquareFootage BuildingLimit
# 0       joistedmasonry   20009  147472          4800       1500000
# 127.0.0.1 - - [05/Dec/2023 17:40:59] "POST /predict_api HTTP/1.1" 200 -
# 1609.6208505717611
#   Jurisdiction  CoverageType             Deductible                  Limit  \
# 0     maryland  bop-building  fixeddollar - 5000.00  standard - 7096952.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0       water      2008       4  classcode:65147                frame  1506.3
#
#       E2Value SquareFootage BuildingLimit
# 0  8308610.34         35000       7096952
# [2023-12-05 17:49:36,308] ERROR in app: Exception on /predict_api [POST]
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#                      ~~~~~^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: '1506.3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\AppData\Local\Temp\ipykernel_23272\903618861.py", line 28, in RiskPrediction
#     df_clean[col] = label_encoders[col].transform(df_clean[col])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py", line 137, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 227, in _encode
#     raise ValueError(f"y contains previously unseen labels: {str(e)}")
# ValueError: y contains previously unseen labels: '1506.3'
# 127.0.0.1 - - [05/Dec/2023 17:49:36] "POST /predict_api HTTP/1.1" 500 -
#   Jurisdiction  CoverageType             Deductible                  Limit  \
# 0     maryland  bop-building  fixeddollar - 5000.00  standard - 7096952.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0       water      2008       4  classcode:65147                frame  1506.3
#
#       E2Value SquareFootage BuildingLimit
# 0  8308610.34         35000       7096952
# [2023-12-05 17:50:04,977] ERROR in app: Exception on /predict_api [POST]
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#                      ~~~~~^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: '1506.3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\AppData\Local\Temp\ipykernel_23272\903618861.py", line 28, in RiskPrediction
#     df_clean[col] = label_encoders[col].transform(df_clean[col])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py", line 137, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 227, in _encode
#     raise ValueError(f"y contains previously unseen labels: {str(e)}")
# ValueError: y contains previously unseen labels: '1506.3'
# 127.0.0.1 - - [05/Dec/2023 17:50:04] "POST /predict_api HTTP/1.1" 500 -
#   Jurisdiction  CoverageType             Deductible                  Limit  \
# 0     maryland  bop-building  fixeddollar - 5000.00  standard - 7096952.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0       water      2008       4  classcode:65147                frame  1506.3
#
#       E2Value SquareFootage BuildingLimit
# 0  8308610.34         35000       7096952
# [2023-12-05 17:51:23,664] ERROR in app: Exception on /predict_api [POST]
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#                      ~~~~~^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: '1506.3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\AppData\Local\Temp\ipykernel_23272\903618861.py", line 28, in RiskPrediction
#     df_clean[col] = label_encoders[col].transform(df_clean[col])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py", line 137, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 227, in _encode
#     raise ValueError(f"y contains previously unseen labels: {str(e)}")
# ValueError: y contains previously unseen labels: '1506.3'
# 127.0.0.1 - - [05/Dec/2023 17:51:23] "POST /predict_api HTTP/1.1" 500 -
#   Jurisdiction  CoverageType             Deductible                  Limit  \
# 0     maryland  bop-building  fixeddollar - 5000.00  standard - 7096952.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0       water      2008       4  classcode:65147                frame  1506.3
#
#       E2Value SquareFootage BuildingLimit
# 0  8308610.34         35000       7096952
# [2023-12-05 17:53:34,083] ERROR in app: Exception on /predict_api [POST]
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#                      ~~~~~^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: '1506.3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\AppData\Local\Temp\ipykernel_23272\903618861.py", line 28, in RiskPrediction
#     df_clean[col] = label_encoders[col].transform(df_clean[col])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py", line 137, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 227, in _encode
#     raise ValueError(f"y contains previously unseen labels: {str(e)}")
# ValueError: y contains previously unseen labels: '1506.3'
# 127.0.0.1 - - [05/Dec/2023 17:53:34] "POST /predict_api HTTP/1.1" 500 -
#   Jurisdiction  CoverageType             Deductible                  Limit  \
# 0     maryland  bop-building  fixeddollar - 5000.00  standard - 7096952.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0       water      2008       4  classcode:65147                frame  1506.3
#
#       E2Value SquareFootage BuildingLimit
# 0  8308610.34         35000       7096952
# [2023-12-05 18:10:26,825] ERROR in app: Exception on /predict_api [POST]
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#                      ~~~~~^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: '1506.3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\AppData\Local\Temp\ipykernel_23272\903618861.py", line 28, in RiskPrediction
#     df_clean[col] = label_encoders[col].transform(df_clean[col])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py", line 137, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SmrutisikhaJena\anaconda3\Lib\site-packages\sklearn\utils\_encode.py", line 227, in _encode
#     raise ValueError(f"y contains previously unseen labels: {str(e)}")
# ValueError: y contains previously unseen labels: '1506.3'
# 127.0.0.1 - - [05/Dec/2023 18:10:26] "POST /predict_api HTTP/1.1" 500 -

# %%
import pandas as pd
data= {
    "Jurisdiction":"Delaware",
    "CoverageType":"BOP-Building",
    "Deductible":"FixedDollar - 1000.00",
    "Limit":"Standard - 217000.00",
    "InjuryCause":"WIND",
    "YearBuilt":"1958",
    "Stories":"1",
    "Comments":"ClassCode:65141",
    "ConstructionTypeDesc":"Frame",
    "ZipCode":"19973",
    "E2Value":"217236",
    "SquareFootage":"1480",
    "BuildingLimit":"217000"
}
df=pd.DataFrame([data])
display(df)
# Out:
#   Jurisdiction  CoverageType             Deductible                 Limit  \
# 0     Delaware  BOP-Building  FixedDollar - 1000.00  Standard - 217000.00
#
#   InjuryCause YearBuilt Stories         Comments ConstructionTypeDesc ZipCode  \
# 0        WIND      1958       1  ClassCode:65141                Frame   19973
#
#   E2Value SquareFootage BuildingLimit
# 0  217236          1480        217000
